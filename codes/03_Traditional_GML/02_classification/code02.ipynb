# %% [markdown]
# # Graph Analysis Techniques without Feature Learning
#
# # Classification with graphs
#
# ## Lab 2 : Soft-Margin SVM
#
# ### Xavier Bresson

# %%
# For Google Colaboratory
import sys, os
if 'google.colab' in sys.modules:
    # mount google drive
    from google.colab import drive
    drive.mount('/content/gdrive')
    path_to_file = '/content/gdrive/My Drive/GML2023_codes/codes/03_Traditional_GML/02_classification'
    print(path_to_file)
    # change current path to the folder containing "path_to_file"
    os.chdir(path_to_file)
    # !pwd

# %%
# Load libraries

# Math
import numpy as np

# Import data
import scipy.io

# Visualization 
# %matplotlib inline
#%matplotlib notebook 
from matplotlib import pyplot
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.max_open_warning': 0})
import time

# Import functions in lib folder
import sys
sys.path.insert(0, 'lib/')

# Import helper functions
# %load_ext autoreload
# %autoreload 2
from lib.utils import compute_purity
from lib.utils import compute_SVM

# Remove warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Data matrix X = linearly separable data points
mat = scipy.io.loadmat('datasets/data_softSVM.mat')
Xtrain = mat['Xtrain']
Cgt_train = mat['C_train_errors'] - 1; Cgt_train = Cgt_train.squeeze()
l_train = mat['l'].squeeze()
n = Xtrain.shape[0]
d = Xtrain.shape[1]
nc = len(np.unique(Cgt_train))
print(n,d,nc)
Xtest = mat['Xtest']
Cgt_test = mat['Cgt_test'] - 1; Cgt_test = Cgt_test.squeeze()
# Out:
# 40 2 2

# %%
plt.figure(1)
size_vertex_plot = 100
plt.scatter(Xtrain[:,0], Xtrain[:,1], s=size_vertex_plot*np.ones(n), c=Cgt_train, color=pyplot.jet())
plt.title('Training Data with 25% ERRORS')
plt.show()

plt.figure(2)
size_vertex_plot = 100
plt.scatter(Xtest[:,0], Xtest[:,1], s=size_vertex_plot*np.ones(n), c=Cgt_test, color=pyplot.jet())
plt.title('Test Data')
plt.show()

# %%
# Run soft SVM
_,_,_,_ = compute_SVM(Xtrain,Cgt_train,l_train,'soft_linear',[0.1],Xtest,Cgt_test,[3,100])
# Out:
# Run Linear SVM
# Construct Linear Kernel

# %%
# Data matrix X = NON-linearly separable data points
mat = scipy.io.loadmat('datasets/data_twomoons_softSVM.mat')
Xtrain = mat['Xtrain']
Cgt_train = mat['C_train_errors'] - 1; Cgt_train = Cgt_train.squeeze()
l_train = mat['l'].squeeze()
n = Xtrain.shape[0]
d = Xtrain.shape[1]
nc = len(np.unique(Cgt_train))
print(n,d,nc)
Xtest = mat['Xtest']
Cgt_test = mat['Cgt_test'] - 1; Cgt_test = Cgt_test.squeeze()
# Out:
# 500 100 2

# %%
plt.figure(10)
size_vertex_plot = 100
plt.scatter(Xtrain[:,0], Xtrain[:,1], s=size_vertex_plot*np.ones(n), c=Cgt_train, color=pyplot.jet())
plt.title('Training Data with 25% ERRORS')
plt.show()

plt.figure(11)
size_vertex_plot = 100
plt.scatter(Xtest[:,0], Xtest[:,1], s=size_vertex_plot*np.ones(n), c=Cgt_test, color=pyplot.jet())
plt.title('Test Data')
plt.show()

# %%
# Run soft SVM
_,_,_,_ = compute_SVM(Xtrain,Cgt_train,l_train,'soft_linear',[0.1],Xtest,Cgt_test,[12,50])
# Out:
# Run Linear SVM
# Construct Linear Kernel
